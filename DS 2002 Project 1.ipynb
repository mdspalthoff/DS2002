# %%
import requests
import sys

import json
                

response = requests.request("GET", "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/istanbul/2022-01-01/2022-12-31?unitGroup=metric&include=days&key=2C4WD8FM3QA2TW494W2K42DX5&contentType=json")
if response.status_code!=200:
  print('Unexpected Status code: ', response.status_code)
  sys.exit()  


# Parse the results as JSON
jsonData = response.json()

# %%
for i in range(0,365):
    x = jsonData["days"][i]
    print("day: ", x["datetime"], ", temp: ", x["temp"])
# Out:
# day:  2022-01-01 , temp:  8.8
# day:  2022-01-02 , temp:  9.6
# day:  2022-01-03 , temp:  10.0
# day:  2022-01-04 , temp:  11.4
# day:  2022-01-05 , temp:  13.0
# day:  2022-01-06 , temp:  14.6
# day:  2022-01-07 , temp:  10.4
# day:  2022-01-08 , temp:  10.0
# day:  2022-01-09 , temp:  9.6
# day:  2022-01-10 , temp:  10.3
# day:  2022-01-11 , temp:  8.8
# day:  2022-01-12 , temp:  3.3
# day:  2022-01-13 , temp:  1.7
# day:  2022-01-14 , temp:  2.4
# day:  2022-01-15 , temp:  5.2
# day:  2022-01-16 , temp:  3.3
# day:  2022-01-17 , temp:  5.5
# day:  2022-01-18 , temp:  5.7
# day:  2022-01-19 , temp:  1.8
# day:  2022-01-20 , temp:  5.0
# day:  2022-01-21 , temp:  6.5
# day:  2022-01-22 , temp:  0.8
# day:  2022-01-23 , temp:  -0.3
# day:  2022-01-24 , temp:  -0.5
# day:  2022-01-25 , temp:  -0.5
# day:  2022-01-26 , temp:  -0.5
# day:  2022-01-27 , temp:  3.0
# day:  2022-01-28 , temp:  4.9
# day:  2022-01-29 , temp:  6.1
# day:  2022-01-30 , temp:  4.0
# day:  2022-01-31 , temp:  6.5
# day:  2022-02-01 , temp:  7.0
# day:  2022-02-02 , temp:  7.6
# day:  2022-02-03 , temp:  4.2
# day:  2022-02-04 , temp:  4.4
# day:  2022-02-05 , temp:  5.0
# day:  2022-02-06 , temp:  7.1
# day:  2022-02-07 , temp:  9.5
# day:  2022-02-08 , temp:  6.1
# day:  2022-02-09 , temp:  5.3
# day:  2022-02-10 , temp:  5.5
# day:  2022-02-11 , temp:  6.2
# day:  2022-02-12 , temp:  7.1
# day:  2022-02-13 , temp:  6.8
# day:  2022-02-14 , temp:  6.0
# day:  2022-02-15 , temp:  4.9
# day:  2022-02-16 , temp:  7.3
# day:  2022-02-17 , temp:  9.3
# day:  2022-02-18 , temp:  9.0
# day:  2022-02-19 , temp:  6.4
# day:  2022-02-20 , temp:  10.0
# day:  2022-02-21 , temp:  11.2
# day:  2022-02-22 , temp:  13.0
# day:  2022-02-23 , temp:  9.1
# day:  2022-02-24 , temp:  6.1
# day:  2022-02-25 , temp:  6.9
# day:  2022-02-26 , temp:  7.9
# day:  2022-02-27 , temp:  7.4
# day:  2022-02-28 , temp:  5.7
# day:  2022-03-01 , temp:  3.4
# day:  2022-03-02 , temp:  4.0
# day:  2022-03-03 , temp:  3.9
# day:  2022-03-04 , temp:  7.0
# day:  2022-03-05 , temp:  6.6
# {'queryCost': 365, 'latitude': 41.062, 'longitude': 28.9888, 'resolvedAddress': 'İstanbul, Türkiye', 'address': 'istanbul', 'timezone': 'Europe/Istanbul', 'tzoffset': 3.0, 'days': [{'datetime': '2022-01-01', 'datetimeEpoch': 1640984400, 'tempmax': 10.5, 'tempmin': 6.8, 'temp': 8.8, 'feelslikemax': 10.5, 'feelslikemin': 5.5, 'feelslike': 8.0, 'dew': 6.9, 'humidity': 87.8, 'precip': 0.303, 'precipprob': 100.0, 'precipcover': 4.17, 'preciptype': ['rain'], 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 18.4, 'windspeed': 9.8, 'winddir': 258.0, 'pressure': 1019.2, 'cloudcover': 75.2, 'visibility': 11.6, 'solarradiation': 35.7, 'solarenergy': 3.0, 'uvindex': 1.0, 'sunrise': '08:29:16', 'sunriseEpoch': 1641014956, 'sunset': '17:46:04', 'sunsetEpoch': 1641048364, 'moonphase': 0.95, 'conditions': 'Rain, Partially cloudy', 'description': 'Partly cloudy throughout the day with late afternoon rain.', 'icon': 'rain', 'stations': ['D8508', 'LTBA', '17063099999', '17061099999', '17064099999', '17060099999'], 'source': 'obs'}, {'datetime': '2022-01-02', 'datetimeEpoch': 1641070800, 'tempmax': 10.7, 'tempmin': 8.2, 'temp': 9.6, 'feelslikemax': 10.7, 'feelslikemin': 7.8, 'feelslike': 9.2, 'dew': 8.1, 'humidity': 90.4, 'precip': 5.932, 'precipprob': 100.0, 'precipcover': 12.5, 'preciptype': ['rain'], 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 20.5, 'windspeed': 13.1, 'winddir': 36.3, 'pressure': 1023.5, 'cloudcover': 78.0, 'visibility': 10.5, 'solarradiation': 27.3, 'solarenergy': 2.2, 'uvindex': 1.0, 'sunrise': '08:29:22', 'sunriseEpoch': 1641101362, 'sunset': '17:46:55', 'sunsetEpoch': 1641134815, 'moonphase': 0.0, 'conditions': 'Rain, Partially cloudy', 'description': 'Partly cloudy throughout the day with a chance of rain throughout the day.', 'icon': 'rain', 'stations': ['D8508', 'LTBA', '17063099999', '17061099999', '17064099999', '17060099999'], 'source': 'obs'}, {'datetime': '2022-01-03', 'datetimeEpoch': 1641157200, 'tempmax': 12.3, 'tempmin': 7.1, 'temp': 10.0, 'feelslikemax': 12.3, 'feelslikemin': 5.5, 'feelslike': 9.5, 'dew': 6.7, 'humidity': 80.6, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': None, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 27.7, 'windspeed': 17.3, 'winddir': 235.6, 'pressure': 1018.1, 'cloudcover': 48.9, 'visibility': 12.3, 'solarradiation': 91.0, 'solarenergy': 7.9, 'uvindex': 4.0, 'sunrise': '08:29:25', 'sunriseEpoch': 1641187765, 'sunset': '17:47:48', 'sunsetEpoch': 1641221268, 'moonphase': 0.02, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': ['D8508', 'LTBA', '17063099999', '17061099999', '17064099999', '17060099999'], 'source': 'obs'}, {'datetime': '2022-01-04', 'datetimeEpoch': 1641243600, 'tempmax': 14.1, 'tempmin': 9.1, 'temp': 11.4, 'feelslikemax': 14.1, 'feelslikemin': 9.1, 'feelslike': 11.4, 'dew': 7.9, 'humidity': 79.1, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': None, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 35.3, 'windspeed': 17.1, 'winddir': 254.6, 'pressure': 1015.3, 'cloudcover': 47.4, 'visibility': 11.8, 'solarradiation': 101.9, 'solarenergy': 8.7, 'uvindex': 4.0, 'sunrise': '08:29:26', 'sunriseEpoch': 1641274166, 'sunset': '17:48:42', 'sunsetEpoch': 1641307722, 'moonphase': 0.05, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': ['D8508', 'LTBA', '17063099999', '17061099999', '17064099999', '17060099999'], 'source': 'obs'}, {'datetime': '2022-01-05', 'datetimeEpoch': 1641330000, 'tempmax': 16.6, 'tempmin': 10.0, 'temp': 13.0, 'feelslikemax': 16.6, 'feelslikemin': 10.0, 'feelslike': 13.0, 'dew': 8.6, 'humidity': 74.7, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': None, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 42.5, 'windspeed': 31.6, 'winddir': 238.1, 'pressure': 1012.2, 'cloudcover': 31.6, 'visibility': 12.5, 'solarradiation': 106.3, 'solarenergy': 9.2, 'uvindex': 4.0, 'sunri ...

# %%
import pandas as pd

# %%
weather_data = []


for i in range(0,365):
    x = jsonData["days"][i]
    weather_data.append(
    {
        "Date": x["datetime"],
        "Temp": x["temp"],
        "Temp Min": x["tempmin"],
        "Temp Max": x["tempmax"],
        "Precipitation": x["precip"],
        "Type of Precip": x["preciptype"],
        "Conditions": x["conditions"],
        "Description": x["description"]
    })
    
weather_data = pd.DataFrame(weather_data)

weather_data
# Out:
#            Date  Temp  Temp Min  Temp Max  Precipitation Type of Precip  \
# 0    2022-01-01   8.8       6.8      10.5          0.303         [rain]
# 1    2022-01-02   9.6       8.2      10.7          5.932         [rain]
# 2    2022-01-03  10.0       7.1      12.3          0.000           None
# 3    2022-01-04  11.4       9.1      14.1          0.000           None
# 4    2022-01-05  13.0      10.0      16.6          0.000           None
# ..          ...   ...       ...       ...            ...            ...
# 360  2022-12-27  10.8       7.0      13.3          0.000           None
# 361  2022-12-28  10.6       8.9      12.5          0.086         [rain]
# 362  2022-12-29   8.8       6.9      11.8          0.052         [rain]
# 363  2022-12-30  10.4       7.6      13.0          0.000           None
# 364  2022-12-31  10.2       7.6      14.0          0.000           None
#
#                  Conditions                                        Description
# 0    Rain, Partially cloudy  Partly cloudy throughout the day with late aft...
# 1    Rain, Partially cloudy  Partly cloudy throughout the day with a chance...
# 2          Partially cloudy                  Partly cloudy throughout the day.
# 3          Partially cloudy                  Partly cloudy throughout the day.
# 4          Partially cloudy                  Partly cloudy throughout the day.
# ..                      ...                                                ...
# 360        Partially cloudy                  Partly cloudy throughout the day.
# 361  Rain, Partially cloudy  Partly cloudy throughout the day with late aft...
# 362  Rain, Partially cloudy       Clearing in the afternoon with morning rain.
# 363        Partially cloudy                         Clearing in the afternoon.
# 364                   Clear               Clear conditions throughout the day.
#
# [365 rows x 8 columns]

# %%
weather_data['Date'] = pd.to_datetime(weather_data['Date'], format = "%Y-%m-%d")
weather_data.head()
# Out:
#         Date  Temp  Temp Min  Temp Max  Precipitation Type of Precip  \
# 0 2022-01-01   8.8       6.8      10.5          0.303         [rain]
# 1 2022-01-02   9.6       8.2      10.7          5.932         [rain]
# 2 2022-01-03  10.0       7.1      12.3          0.000           None
# 3 2022-01-04  11.4       9.1      14.1          0.000           None
# 4 2022-01-05  13.0      10.0      16.6          0.000           None
#
#                Conditions                                        Description
# 0  Rain, Partially cloudy  Partly cloudy throughout the day with late aft...
# 1  Rain, Partially cloudy  Partly cloudy throughout the day with a chance...
# 2        Partially cloudy                  Partly cloudy throughout the day.
# 3        Partially cloudy                  Partly cloudy throughout the day.
# 4        Partially cloudy                  Partly cloudy throughout the day.

# %%
mall = pd.read_csv("C:/Users/matth/OneDrive/Documents/UVA/Third Year/DS 2002/customer_shopping_data.csv")

mall["year"] = mall.invoice_date.str[-2:]

# %%
mall.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall year
# 0    Credit Card     5/8/2022          Kanyon   22
# 1     Debit Card   12/12/2021  Forum Istanbul   21
# 2           Cash    9/11/2021       Metrocity   21
# 3    Credit Card   16/05/2021    Metropol AVM   21
# 4           Cash   24/10/2021          Kanyon   21

# %%
mall = mall[mall.year=='22']
mall.head()
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
# 11    I139207     C191708  Female   29            Books         1    15.15
#
#    payment_method invoice_date      shopping_mall year
# 0     Credit Card     5/8/2022             Kanyon   22
# 5     Credit Card   24/05/2022     Forum Istanbul   22
# 6            Cash   13/03/2022       Istinye Park   22
# 10           Cash   25/12/2022          Metrocity   22
# 11    Credit Card   28/10/2022  Emaar Square Mall   22

# %%
mall['invoice_date'] = pd.to_datetime(mall['invoice_date'], format = "%d/%m/%Y")
mall.head()
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
# 11    I139207     C191708  Female   29            Books         1    15.15
#
#    payment_method invoice_date      shopping_mall year
# 0     Credit Card   2022-08-05             Kanyon   22
# 5     Credit Card   2022-05-24     Forum Istanbul   22
# 6            Cash   2022-03-13       Istinye Park   22
# 10           Cash   2022-12-25          Metrocity   22
# 11    Credit Card   2022-10-28  Emaar Square Mall   22

# %%
len(mall)
# Out:
# 45551

# %%
cust = pd.read_csv("C:/Users/matth/OneDrive/Documents/UVA/Third Year/DS 2002/Mall_Customers.csv")
cust.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
cgroup = cust.groupby(['Gender', 'Age'])['Annual Income (k$)', 'Spending Score (1-100)'].mean()
# Out:
# C:\Users\matth\AppData\Local\Temp/ipykernel_11304/3026512058.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cgroup = cust.groupby(['Gender', 'Age'])['Annual Income (k$)', 'Spending Score (1-100)'].mean()

# %%
cgroup.reset_index(inplace = True)

# %%
cgroup[(cgroup.Gender == 'Male') & (cgroup['Age'] == 20)]
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 45   Male   20           51.666667                    40.0

# %%
cgroup.summarize(include = 'all')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11304/3073376411.py in <module>
# ----> 1 cgroup.summarize(include = 'all')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'summarize'
